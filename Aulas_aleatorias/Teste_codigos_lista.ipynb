# %%
compras = ['leite', 'arroz', 'queijo', 'aveia', 'banana', 'feijão', 'farinha', 'sabonete', 'shampoo', 'tomate']

mercado = ['água', 'suco']

#  Adiciona um item na lista:
compras.append ('cebola')
print(compras)

#  Adiciona um item em uma posição na lista:
compras.insert(3, 'alho')
print(compras)

# Exclui um item da lista:
compras.pop(5) #  excluiu o item "banana(5)"
#  ou
#  compras.remove('banana')
#  ou
#  if 'banana' in compras:
  #  compras.remove('banana')
print(compras)
# Out:
# ['leite', 'arroz', 'queijo', 'aveia', 'banana', 'feijão', 'farinha', 'sabonete', 'shampoo', 'tomate', 'cebola']
# ['leite', 'arroz', 'queijo', 'alho', 'aveia', 'banana', 'feijão', 'farinha', 'sabonete', 'shampoo', 'tomate', 'cebola']
# ['leite', 'arroz', 'queijo', 'alho', 'aveia', 'feijão', 'farinha', 'sabonete', 'shampoo', 'tomate', 'cebola']
