# %%
range(10) #  Cria um intervalo de 0 a 10.

# %%
list(range(10)) # Converte um intervalo de 0 a 10 em lista.

# %%
teste_cont = list(range(1, 11))

for cont in teste_cont:
  print(f'Você removeu {cont} da lista!')

# %%
for cont in range(1, 11):
  print(f'Você removeu {cont} da lista!')
