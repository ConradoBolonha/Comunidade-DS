# %% [markdown]
# 1 - Um programador Jr precisa construir uma mini calculadora. Esse calculadora
# segue os seguintes padrões: Se o usuário digital um valor menor ou igual a 5,
# a calculadora vai multiplicar esse valor por 10 e retornar o valor resultantes
# para o usuário. Por outro lado, se o usuário digitar um número entre 6 e 10, a
# calculadora multiplica por 20 o número digitado pelo usuário e se o usuário
# digitar um valor maior ou igual a 11, a calculadora soma 100 ao número
# digitado. Ajude o programador Jr a construir essa calculadora, fornecendo o
# diagrama de blocos para ele

# %%
numero = int(input('Digite um número: '))

if numero <= 5:
  numero = numero * 10
  print(f'O resultado é {numero}')
else:
  if numero <= 10:
    numero = numero * 20
    print(f'O resultado é {numero}')

  else:
    print(f'O resultado é {numero + 100}')
# Out:
# Digite um número: 54
# O resultado é 154

# %% [markdown]
# 2 - Crie um script em Python que exiba, 52 vezes, a seguinte
# mensagem “Um valor foi removido da lista”. Além disso, esse script deve
# mostrar, junto com a mensagem, o número de vezes em que a mensagem foi
# exibida.

# %%
mensag = 'Um valor foi removido da lista'

if mensag == 'Um valor foi removido da lista':
 print(f'{mensag}')

# %% [markdown]
# 3 - Um Cientista de Dados Jr precisa criar uma algoritmo que seja capaz de
# calcular a média ponderada dos valores digitados pelo usuário. O usuário é
# capaz de digitar 8 valores. O primeiro número tem peso 0.5 , o segundo 1.0,
# o terceiro 1.5 até o último valor que tem peso 4, ou seja, os pesos são
# acrescidos de 0.5 para cada valor. Por tanto, o algoritmo deve ser capaz de
# calcular a média ponderada dos oito valores digitados pelo usuário, cada
# valor com o seu respectivo peso.

# %%
valor = int(input('Digite um valor: '))

# %% [markdown]
# 4 - Converta o pseudocódigo abaixo para código Python.
#
# var
#   valor, resultado
# inicio
#   leia valor
# se valor é maior que 10
#   resultado <- valor * 100
#   escreva "O resultado é igual a {resultado}"
# senao
#   resultado <- valor + 10
#   escreva "O resultado é igual a {resultado}"
#
# fim

# %%
valor = int(input('Digite um valor: '))
resultado = valor

if valor >= 10:
  resultado = valor * 100
  print(f'O resultado é igual a {resultado}')

else:
  valor <= 9
  print(f'O resultado é igual a {resultado + 10}')
# Out:
# Digite um valor: 9
# O resultado é igual a 19

# %% [markdown]
# 5 - Converta o pseudocódigo abaixo para código Python.
#
# var
#   idade
#
# inicio
#   leia idade
# se idade é maior ou igual a 18
#   escreva "É maior de idade"
# senao
#   escreva "Não é maior de idade"
# fim

# %%
idade = int(input('Digite sua idade: '))

if idade <= 17:
  print(f'Você tem {idade} anos e é menor de idade!')
else:
  print(f'Você tem {idade} anos e é maior de idade!')
# Out:
# Digite sua idade: 17
# Você tem 17 anos e é menor de idade!

# %% [markdown]
# 6 - Um programador Jr precisa criar um algoritmo que consiga fazer a
# comparação entre três valores digitados pelo usuário e exibir qual é o maior e
# qual é o menor valor digitado. Ajude o programador a desenvolver um
# algoritmo que receba três valores digitados pelo usuário e verifique qual
# deles é o maior e qual deles é o menor valor, e exiba ambos na tela.

# %%
num_1 = int(input('Digite um valor: '))
num_2 = int(input('Digite um segundo valor: '))
num_3 = int(input('Digite um terceiro valor: '))
num_maior = num_1
num_menor = num_2

if num_1 > num_2 > num_3:
  num_maior = num_1
  num_menor = num_3

if num_1 < num_2 > num_3:
  num_maior = num_2
  num_menor = num_3

else:
  num_maior = num_3
  num_menor =

# %% [markdown]
# 7 - Desenvolva um script em Python capaz de calcular a média harmônica entre
# 5 números. Por exemplo: 2, 3, 5, 6 e 9

# %%
v1 = 6
v2 = 5
v3 = 3
v4 = 1
v5 = 9
numerador = 5
denom = (1/v1) + (1/v2) + (1/v3) + (1/v4) + (1/v5)

media = numerador / denom

print(f'A média harmônica é {media}')
# Out:
# A média harmônica é 2.7607361963190185

# %% [markdown]
# 8 - Crie um script em Python capaz de calcular o desvio padrão de um
# sequência de 10 números. Por exemplo: 53, 9, 54, 91, 84, 54, 7, 51, 60, 86

# %%
media = (12 + 9 + 22 + 14 + 17 + 5 + 4 + 8 + 3 + 16) / 10
print()

soma = ((12 - media) ** 1/2 + (9 - media) ** 1/2 + (22 - media) ** 1/2 + (14 - media) ** 1/2 + (17 - media) ** 1/2 + (5 - media) ** 1/2 + (4 - media) ** 1/2 + (8 - media) ** 1/2 + (3 - media) ** 1/2 + (16 - media))

desvio = soma ** 1/2

print (f'A média dos valores é {media} e o desvio é {desvio}')
# Out:
# A média dos valore é 11.0 e o desvio é 1.25
